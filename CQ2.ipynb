# %%
# install these 2 packages

# %% [markdown]
# !pip install folium

# %% [markdown]
# !pip install geojson

# %%
import folium
import numpy as np
import pandas as pd

import geojson
import os
import json

from branca.colormap import linear

# %%
#importing json data
json_data = json.load(open('taxi_zones.json'))

# %%
# directory path for csv files (dataset from Jan to Jun 2018)
df_names=['data/yellow_tripdata_2018-01.csv','data/yellow_tripdata_2018-02.csv',
          'data/yellow_tripdata_2018-03.csv','data/yellow_tripdata_2018-04.csv',
         'data/yellow_tripdata_2018-05.csv','data/yellow_tripdata_2018-06.csv']

# taxi_zone_lookup.csv file
taxi_zone_lookup = pd.read_csv('data/taxi_zone_lookup.csv',usecols=['Zone','LocationID'])

# %%
#DO A START MAP

# %%
def takeStartZones(df_names,taxi_zone_lookup):

    res=pd.DataFrame() #list to store parts of dataframe grouped by Borough and payment_type

    for i,df_name in enumerate(df_names): #repeating it for every fail(aka month)
            # load the ith dataframe, taking only 2 columns
            df = pd.read_csv(df_name,usecols= ['PULocationID'],nrows=10000)

            # merging it with taxi_zone_lookup file(left-join) 
            df=pd.merge(df,taxi_zone_lookup,how='left',left_on='PULocationID',right_on='LocationID')


            res=res.append(df)
    return res

# %%
df=takeStartZones(df_names,taxi_zone_lookup)

# %%
df.head(3)
# Out:
#    PULocationID  LocationID                   Zone
# 0            45          45              Chinatown
# 1           239         239  Upper West Side South
# 2           236         236  Upper East Side North

# %%
df=df.groupby('Zone').count()

# %%
df.head(3)
# Out:
#                          PULocationID  LocationID
# Zone
# Allerton/Pelham Gardens             1           1
# Alphabet City                     178         178
# Astoria                           169         169

# %%
colormap = linear.YlGn_09.scale(
    #max and min number of trip counts for each NYC zone
    df.PULocationID.min(),
    df.PULocationID.max())

colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffe5;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffe5;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffe4;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ffffe3;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ffffe3;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ffffe2;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ffffe1;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ffffe0;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#feffe0;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#feffdf;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#feffde;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#feffde;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#f
# ...

# %%
df = df['PULocationID']

df['Astoria']
# Out:
# 169

# %%
json_data['features'][0]['properties']['zone']
# Out:
# 'Newark Airport'

# %%
len(json_data['features'])
# Out:
# 263

# %%
list_of_zones=[]
for i in range(len(json_data['features'])):
    list_of_zones.append(json_data['features'][i]['properties']['zone'])

# %%
list_of_zones[0:5]
# Out:
# ['Newark Airport',
#  'Jamaica Bay',
#  'Allerton/Pelham Gardens',
#  'Alphabet City',
#  'Arden Heights']

# %%
'Astoria' in df.index
# Out:
# True

# %%
df['Astoria']
# Out:
# 169

# %%
json_data['features'][0]['properties']['zone'] in df.index
# Out:
# False

# %%
m = folium.Map(location=[40.7128, -74.0060])

folium.GeoJson(
    json_data,
    style_function=lambda feature: {
        'fillColor': colormap(df[feature['properties']['zone']]) if feature['properties']['zone'] in df.index else '#ffff00',
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5',
        'fillOpacity': 0.9,
    }
).add_to(m)

folium.LayerControl().add_to(m)

m.save(os.path.join('GeoJSON_and_choropleth_start.html'))

# %%
# AN END MAP

# %%
def takeEndZones(df_names,taxi_zone_lookup):
    res=pd.DataFrame() #list to store parts of dataframe 

    for i,df_name in enumerate(df_names): #repeating it for every fail(aka month)
            # load the ith dataframe, taking only 2 columns
            df = pd.read_csv(df_name,usecols= ['DOLocationID'],nrows=10000)

            # merging it with taxi_zone_lookup file(left-join) 
            df=pd.merge(df,taxi_zone_lookup,how='left',left_on='DOLocationID',right_on='LocationID')


            res=res.append(df)
    return res

# %%
df=takeEndZones(df_names,taxi_zone_lookup)

# %%
df.head()
# Out:
#    DOLocationID  LocationID                     Zone
# 0           114         114  Greenwich Village South
# 1            13          13        Battery Park City
# 2           161         161           Midtown Center
# 3           148         148          Lower East Side
# 4           260         260                 Woodside

# %%
df=df.groupby('Zone').count()

colormap = linear.YlGn_09.scale(
    df.DOLocationID.min(),
    df.DOLocationID.max())

print(colormap(5.0))

colormap

list_of_zones=[]
for i in range(len(json_data['features'])):
    list_of_zones.append(json_data['features'][i]['properties']['zone'])
# Out:
# #ffffe5

# %%
df = df['DOLocationID']

# %%
m = folium.Map(location=[40.7128, -74.0060])

folium.GeoJson(
    json_data,
    style_function=lambda feature: {
        'fillColor': colormap(df[feature['properties']['zone']]) if feature['properties']['zone'] in df.index else '#ffff00',
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5',
        'fillOpacity': 0.9,
    }
).add_to(m)

folium.LayerControl().add_to(m)

m.save(os.path.join('GeoJSON_and_choropleth_end.html'))

# %%
#testing how json works
json_data['features'][0]['properties']['zone']
# Out:
# 'Newark Airport'

# %%
#more testing
m = folium.Map(location=[40.7128, 74.0060])#, zoom_start=4)#[43, -100],

folium.GeoJson(json_data).add_to(m)

m.save(os.path.join('results', 'GeoJSON_and_choropleth_0.html'))

#m

# %%
#more testing
m = folium.Map(location=[40.7128, -74.0060])#, zoom_start=4)#[43, -100],

folium.GeoJson(json_data).add_to(m)

m.save(os.path.join('results', 'GeoJSON_and_choropleth_mamamia.html'))

#m

# %%
taxi_zone_lookup.shape
# Out:
# (265, 2)

# %%
zone_lst = taxi_zone_lookup.Zone.unique()

# %%
len(zone_lst)
# Out:
# 262

# %% [markdown]
# # Finalized notebook if the previous is OK ;)

# %%
import folium
import numpy as np
import pandas as pd

import geojson
import os
import json

from branca.colormap import linear

# %%
#importing json data
json_data = json.load(open('taxi_zones.json'))

# %%
# directory path for csv files (dataset from Jan to Jun 2018)
df_names=['data/yellow_tripdata_2018-01.csv','data/yellow_tripdata_2018-02.csv',
          'data/yellow_tripdata_2018-03.csv','data/yellow_tripdata_2018-04.csv',
         'data/yellow_tripdata_2018-05.csv','data/yellow_tripdata_2018-06.csv']

# taxi_zone_lookup.csv file
taxi_zone_lookup = pd.read_csv('data/taxi_zone_lookup.csv',usecols=['Zone','LocationID'])

# %% [markdown]
# # START MAP

# %%
def takeStartZones(df_names,taxi_zone_lookup):

    res=pd.DataFrame() #list to store parts of dataframe grouped by Borough and payment_type

    for i,df_name in enumerate(df_names): #repeating it for every fail(aka month)
            # load the ith dataframe, taking only 2 columns
            df = pd.read_csv(df_name,usecols= ['PULocationID'],nrows=100000)

            # merging it with taxi_zone_lookup file(left-join) 
            df=pd.merge(df,taxi_zone_lookup,how='left',left_on='PULocationID',right_on='LocationID')


            res=res.append(df)
    res=res.groupby('Zone').count()
    return res

# %%
df=takeStartZones(df_names,taxi_zone_lookup)

# %%
colormap = linear.YlGn_09.scale(
    #max and min number of trip counts for each NYC zone
    df.PULocationID.min(),
    df.PULocationID.max())
colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffe5;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffe5;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffe4;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ffffe3;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ffffe3;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ffffe2;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ffffe1;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ffffe0;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#feffe0;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#feffdf;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#feffde;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#feffde;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#f
# ...

# %%
df = df['PULocationID']

#NYC COORDINATES
m = folium.Map(location=[40.7128, -74.0060])

folium.GeoJson(
    json_data,
    style_function=lambda feature: {
        'fillColor': colormap(df[feature['properties']['zone']]) if feature['properties']['zone'] in df.index else '#ffff00',
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5',
        'fillOpacity': 0.9,
    }
).add_to(m)

folium.LayerControl().add_to(m)

m.save(os.path.join('GeoJSON_and_choropleth_start.html'))

# %% [markdown]
# # END MAP

# %%
def takeEndZones(df_names,taxi_zone_lookup):
    res=pd.DataFrame() #list to store parts of dataframe 

    for i,df_name in enumerate(df_names): #repeating it for every fail(aka month)
            # load the ith dataframe, taking only 2 columns
            df = pd.read_csv(df_name,usecols= ['DOLocationID'],nrows=100000)

            # merging it with taxi_zone_lookup file(left-join) 
            df=pd.merge(df,taxi_zone_lookup,how='left',left_on='DOLocationID',right_on='LocationID')


            res=res.append(df)
    res=res.groupby('Zone').count()
    return res

# %%
df=takeEndZones(df_names,taxi_zone_lookup)

# %%
colormap = linear.YlGn_09.scale(
    df.DOLocationID.min(),
    df.DOLocationID.max())

colormap
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#ffffe5;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#ffffe5;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#ffffe4;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#ffffe3;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#ffffe3;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#ffffe2;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#ffffe1;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#ffffe0;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#feffe0;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#feffdf;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#feffde;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#feffde;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#f
# ...

# %%
df = df['DOLocationID']

# %%
m = folium.Map(location=[40.7128, -74.0060])

folium.GeoJson(
    json_data,
    style_function=lambda feature: {
        'fillColor': colormap(df[feature['properties']['zone']]) if feature['properties']['zone'] in df.index else '#ffff00',
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5',
        'fillOpacity': 0.9,
    }
).add_to(m)

folium.LayerControl().add_to(m)

m.save(os.path.join('GeoJSON_and_choropleth_end.html'))
